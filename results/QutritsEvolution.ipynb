# %%
import torch.cuda as cuda
import matplotlib.pyplot as plt

# %%
from modules import *

# %%
device  = "cuda" if cuda.is_available() else "cpu"
print(f"currently used device : {device}")
# Out:
# currently used device : cpu

# %%
n = 3
fig = gen_results_for_completely_mixed(n,Synch_0,device = device)

plt.tight_layout()
x_ticks = [0.4,0.5,0.6]
x_labels = [r'$\frac{2}{5}\pi$', r'$\frac{1}{2}\pi$', r'$\frac{3}{5}\pi$']

y_ticks = [0.4,0.5,0.6]
y_labels = [r'$\frac{2}{5}\pi$', r'$\frac{1}{2}\pi$', r'$\frac{3}{5}\pi$']

plt.xticks(x_ticks, x_labels)
plt.yticks(y_ticks, y_labels)

#plt.savefig("QutritDM.pdf", format="pdf", bbox_inches="tight")
plt.show()
